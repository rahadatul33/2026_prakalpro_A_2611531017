# %% [markdown]
# <div style="font-family:'Times New Roman', Times, serif; font-size: 18px;">
# <div align="center">
#
# ## **LAPORAN PRAKTIKUM**
#
# ## **ALGORITMA DAN PEMROGRAMAN**
#
# ## **“Operator pada Python”**
#
# ## **Disusun Oleh :**
#
# ## **Rahadatul Aisha Tetriana Putri**
#
# ## **2611531017**
#
# ## **Dosen Pengampu:**
#
# ## **Wahyudi.DR.. S.T.M.T**
#
# ## **Asisten Praktikum:**
#
# ## **Rifki Yuliandra**
#
# <br>
# <img src=images/logo_unandd.png width=200>
# <br>
#
# ## **FAKULTAS TEKNOLOGI INFORMASI**
#
# ## **DEPARTEMEN INFORMATIKA**
#
# ## **UNIVERSITAS ANDALAS**
#
# ## **2026**
#
# </div>

# %% [markdown]
# <div style="font-family:'Times New Roman', Times, serif; font-size: 18px;">
# <h1 align=center> KATA PENGANTAR </h1>
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum Alpro 3 yang telah dilaksanakan sebagai pertemuan ke-3 untuk mata kuliah Praktikum Algoritma dan Pemrograman. Praktikum ini berfokus pada pembahasan implementasi berbagai jenis operator pada bahasa pemrograman Python, yaitu operator aritmatika, operator assignment, operator keanggotaan, operator logika, operator keanggotaan, serta operator perbandingan.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep operator dalam bahasa pemrograman Ptyhon pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# <div style="font-family:'Times New Roman', Times, serif; font-size: 18px;">
# <h1 align=center> BAB I <br> PENDAHULUAN </h1>
#
# ## 1.1 Latar Belakang
# Python merupakan salah satu bahasa pemrograman yang banyak digunakan karena memiliki penulisan yang sederhana dan mudah dipahami. Dalam membuat suatu program, selain pemahaman terhadap tipe data, diperlukan juga pemahaman terhadap operator yang digunakan untuk mengolah data tersebut agar program dapat berjalan sesuai dengan tujuan yang diinginkan. Pada praktikum ini, dipelajari beberapa jenis operator dalam Python, yaitu operator aritmatika, assignment, bitwise, logika, keanggotaan, dan perbandingan. Operator aritmatika digunakan untuk melakukan operasi perhitungan matematis, operator assignment digunakan untuk memberikan atau memperbarui nilai suatu variabel, operator bitwise digunakan untuk mengolah data dalam bentuk biner, operator logika digunakan untuk mengombinasikan atau membalik nilai boolean, operator keanggotaan digunakan untuk memeriksa keberadaan suatu nilai dalam sebuah kumpulan data, sedangkan operator perbandingan digunakan untuk membandingkan dua nilai. Melalui praktikum ini, keenam jenis operator tersebut diterapkan dalam beberapa program sederhana sehingga dapat membantu memahami penggunaan operator dalam pembuatan program menggunakan Python.
#
# ## 1.2 Tujuan
# 1. Mengetahui cara kerja operator aritmatika dan assignment dalam mengolah nilai suatu variabel di Python.
# 2. Memahami cara kerja operator bitwise dalam mengolah data pada bentuk biner.
# 3. Menerapkan operator logika untuk mengombinasikan atau membalik nilai boolean pada suatu program.
# 4. Membandingkan penggunaan operator keanggotaan dan operator perbandingan dalam pengecekan data.
#
# ## 1.3 Manfaat
# 1. Menambah wawasan mengenai berbagai jenis operator yang tersedia dalam bahasa pemrograman Python.
# 2. Memudahkan penyusunan program yang melibatkan perhitungan, pengecekan kondisi, maupun pembandingan nilai.
# 3. Menjadi bekal untuk mengaplikasikan operator secara tepat pada program yang lebih kompleks ke depannya.

# %% [markdown]
# <div style="font-family:'Times New Roman', Times, serif; font-size: 18px;">
# <h1 align=center> BAB II <br> PEMBAHASAN </h1>
#
# ## 2.1 Dasar Teori <br>
# Pada praktikum ini dibahas beberapa jenis operator dalam bahasa pemrograman Python, yaitu operator aritmatika, assignment, bitwise, logika, keanggotaan, serta perbandingan. Operator-operator tersebut digunakan untuk mengolah data dan membentuk kondisi tertentu sesuai kebutuhan program, sehingga program dapat berjalan dan menghasilkan keluaran sesuai yang diharapkan. Dasar teori dari masing-masing operator yang dipelajari adalah sebagai berikut:
#
# ### 2.1.1 Operator Aritmatika<br>
# Operator aritmatika merupakan operator yang digunakan untuk melakukan perhitungan matematis terhadap dua buah nilai atau lebih. Operator ini terdiri dari penjumlahan (+), pengurangan (-), perkalian (*), pembagian (/), pembagian bulat (//), sisa bagi atau modulus (%), dan pangkat (**). Pembagian bulat menghasilkan nilai hasil bagi tanpa angka desimal, sedangkan sisa bagi menghasilkan nilai sisa dari suatu pembagian. Operator aritmatika banyak digunakan dalam program yang melibatkan proses perhitungan angka.
#
# ### 2.1.2 Operator Assignment<br>
# Operator assignment digunakan untuk memberikan atau memperbarui nilai suatu variabel. Bentuk paling sederhana adalah tanda sama dengan (=), yang digunakan untuk menyimpan suatu nilai ke dalam variabel. Selain itu, Python juga menyediakan operator assignment gabungan seperti penambahan (+=), pengurangan (-=), perkalian (*=), pembagian (/=), pembagian bulat (//=), sisa bagi (%=), dan pemangkatan (**=). Operator assignment gabungan memungkinkan suatu variabel diperbarui nilainya berdasarkan nilai sebelumnya tanpa perlu menuliskan ulang nama variabel secara lengkap, sehingga penulisan program menjadi lebih ringkas.
#
# ### 2.1.3 Operator Bitwise<br>
# Operator bitwise merupakan operator yang bekerja pada tingkat bit atau representasi biner dari suatu bilangan. Operator ini terdiri dari AND (&), OR (|), XOR (^), NOT (~), geser kiri (<<), dan geser kanan (>>). Operator AND, OR, dan XOR membandingkan bit dari dua bilangan, operator NOT membalik seluruh bit dari suatu bilangan, sedangkan operator geser kiri dan geser kanan menggeser posisi bit sejumlah tertentu ke arah kiri atau kanan. Operator bitwise sering digunakan dalam program yang berkaitan dengan pengolahan data pada level biner.
#
# ### 2.1.4 Operator Logika<br>
# Operator logika digunakan untuk mengombinasikan atau membalik nilai boolean dalam suatu program. Operator ini terdiri dari and, or, dan not. Operator and menghasilkan nilai True apabila kedua kondisi bernilai True, operator or menghasilkan nilai True apabila salah satu kondisi bernilai True, sedangkan operator not digunakan untuk membalik nilai boolean yang ada. Operator logika biasanya digunakan ketika suatu program perlu menggabungkan lebih dari satu kondisi sekaligus.
#
# ### 2.1.5 Operator Keanggotaan<br>
# Operator keanggotaan digunakan untuk memeriksa apakah suatu nilai terdapat di dalam suatu kumpulan data seperti list, terdiri dari in yang bernilai True apabila nilai ditemukan, dan not in yang bernilai True apabila nilai tidak ditemukan. Sementara itu, operator identitas digunakan untuk membandingkan apakah dua variabel merujuk pada objek yang sama di dalam memori, bukan sekadar membandingkan nilainya, dan terdiri dari is serta is not. Dua variabel dapat memiliki nilai yang sama tetapi merupakan objek yang berbeda, sehingga hasil operator identitas dapat berbeda dengan hasil operator perbandingan nilai (==).
#
# ### 2.1.6 Operator Perbandingan<br>
# Operator perbandingan digunakan untuk membandingkan dua buah nilai dan menghasilkan nilai boolean sebagai hasilnya. Operator ini terdiri dari lebih besar dari (>), lebih kecil dari (<), lebih besar dari atau sama dengan (>=), lebih kecil dari atau sama dengan (<=), sama dengan (==), dan tidak sama dengan (!=). Python juga mendukung perbandingan berantai, yaitu penulisan lebih dari satu operator perbandingan dalam satu ekspresi, seperti 0 < x < 100, yang akan diproses sebagai gabungan dari dua kondisi perbandingan sekaligus.

# %% [markdown]
# <div style="font-family:'Times New Roman', Times, serif; font-size: 18px;">
#
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "Aritmatika_2611531017"

# %%
# Buat file dengan nama aritmatika_NIM.py
# Buat program untuk operator aritmatika dalam Python
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer

angka1_1017 = int(input("Input angka-1: "))
angka2_1017 = int(input("Input angka-2: "))

# Penjumlahan
hasil_1017 = angka1_1017 + angka2_1017
print("\nOperator Penjumlahan")
print("Hasil =", hasil_1017)

# Pengurangan
hasil_1017 = angka1_1017 - angka2_1017
print("\nOperator Pengurangan")
print("Hasil =", hasil_1017)

# Perkalian
hasil_1017 = angka1_1017 * angka2_1017
print("\nOperator Perkalian")
print("Hasil =", hasil_1017)

# Pembagian, pembagian bulat, dan sisa bagi
if angka2_1017 != 0:
    hasil_1017 = angka1_1017 / angka2_1017
    print("\nOperator Pembagian")
    print("Hasil =", hasil_1017)

    hasil_1017 = angka1_1017 // angka2_1017
    print("\nOperator Pembagian Bulat")
    print("Hasil =", hasil_1017)

    hasil_1017 = angka1_1017 % angka2_1017
    print("\nOperator Sisa Bagi")
    print("Hasil =", hasil_1017)
else:
    print("Angka kedua tidak boleh bernilai 0.")

# Pangkat
hasil_1017 = angka1_1017 ** angka2_1017
print("\nOperator Pangkat")
print("Hasil =", hasil_1017)
# Out:
# Operator Penjumlahan
# Hasil = 13
#
# Operator Pengurangan
# Hasil = 5
#
# Operator Perkalian
# Hasil = 36
#
# Operator Pembagian
# Hasil = 2.25
#
# Operator Pembagian Bulat
# Hasil = 2
#
# Operator Sisa Bagi
# Hasil = 1
#
# Operator Pangkat
# Hasil = 6561

# %% [markdown]
# <div style="font-family:'Times New Roman', Times, serif; font-size: 18px;">
#
# **Penjelasan**
#
# 1. Baris 1 sampai baris 5 berfungsi sebagai komentar yang memberikan keterangan bahwa program ini digunakan untuk membuat file bernama aritmatika_NIM.py, yang berisi program operator aritmatika dalam Python, menggunakan penamaan variabel dengan tambahan 4 digit NIM, memanfaatkan fungsi input(), serta mengonversi nilai yang dimasukkan menjadi tipe data integer. Komentar tersebut tidak dijalankan sebagai bagian dari proses program.
# 2. Baris 7 berfungsi untuk mendeklarasikan variabel angka1_1017 dan mengisinya dengan nilai yang dimasukkan pengguna melalui fungsi input(), yang kemudian dikonversi menjadi tipe data integer menggunakan fungsi int().
# 3. Baris 8 berfungsi untuk mendeklarasikan variabel angka2_1017 dengan cara yang sama seperti baris 7, yaitu menerima masukan dari pengguna dan mengonversinya menjadi tipe data integer.
# 4. Baris 10 berfungsi sebagai komentar yang menjelaskan bahwa bagian program selanjutnya menunjukkan penggunaan operator penjumlahan.
# 5. Baris 11 berfungsi untuk menghitung hasil penjumlahan antara angka1_1017 dan angka2_1017 menggunakan operator aritmatika (+), kemudian hasilnya disimpan dalam variabel hasil_1017.
# 6. Baris 12 berfungsi untuk menampilkan teks "Operator Penjumlahan" sebagai judul keluaran menggunakan fungsi print().
# 7. Baris 13 berfungsi untuk menampilkan teks "Hasil =" beserta nilai variabel hasil_1017 menggunakan fungsi print(), sehingga hasil penjumlahan dapat dilihat oleh pengguna.
# 8. Baris 15 berfungsi sebagai komentar yang menjelaskan bahwa bagian program selanjutnya menunjukkan penggunaan operator pengurangan.
# 9. Baris 16 berfungsi untuk menghitung hasil pengurangan antara angka1_1017 dan angka2_1017 menggunakan operator aritmatika (-), kemudian hasilnya disimpan kembali ke dalam variabel hasil_1017.
# 10. Baris 17 berfungsi untuk menampilkan teks "Operator Pengurangan" sebagai judul keluaran menggunakan fungsi print().
# 11. Baris 18 berfungsi untuk menampilkan teks "Hasil =" beserta nilai variabel hasil_1017 menggunakan fungsi print(), sehingga hasil pengurangan dapat dilihat oleh pengguna.
# 12. Baris 20 berfungsi sebagai komentar yang menjelaskan bahwa bagian program selanjutnya menunjukkan penggunaan operator perkalian.
# 13. Baris 21 berfungsi untuk menghitung hasil perkalian antara angka1_1017 dan angka2_1017 menggunakan operator aritmatika (*), kemudian hasilnya disimpan ke dalam variabel hasil_1017.
# 14. Baris 22 berfungsi untuk menampilkan teks "Operator Perkalian" sebagai judul keluaran menggunakan fungsi print().
# 15. Baris 23 berfungsi untuk menampilkan teks "Hasil =" beserta nilai variabel hasil_1017 menggunakan fungsi print(), sehingga hasil perkalian dapat dilihat oleh pengguna.
# 16. Baris 25 berfungsi sebagai komentar yang menjelaskan bahwa bagian program selanjutnya menunjukkan penggunaan operator pembagian, pembagian bulat, dan sisa bagi.
# 17. Baris 26 berfungsi untuk membuat percabangan kondisi menggunakan pernyataan if, yang memeriksa apakah angka2_1017 tidak sama dengan 0 (angka2_1017 != 0), guna menghindari kesalahan pembagian dengan nol.
# 18. Baris 27 berfungsi untuk menghitung hasil pembagian antara angka1_1017 dan angka2_1017 menggunakan operator aritmatika (/), yang hanya dijalankan apabila kondisi pada baris 26 bernilai True.
# 19. aris 28 berfungsi untuk menampilkan teks "Operator Pembagian" sebagai judul keluaran menggunakan fungsi print().
# 20. Baris 29 berfungsi untuk menampilkan teks "Hasil =" beserta nilai variabel hasil_1017 menggunakan fungsi print(), sehingga hasil pembagian dapat dilihat oleh pengguna.
# 21. Baris 31 berfungsi untuk menghitung hasil pembagian bulat antara angka1_1017 dan angka2_1017 menggunakan operator aritmatika (//), yang menghasilkan nilai bulat tanpa angka desimal.
# 22. Baris 32 berfungsi untuk menampilkan teks "Operator Pembagian Bulat" sebagai judul keluaran menggunakan fungsi print().
# 23. Baris 33 berfungsi untuk menampilkan teks "Hasil =" beserta nilai variabel hasil_1017 menggunakan fungsi print(), sehingga hasil pembagian bulat dapat dilihat oleh pengguna.
# 24. Baris 35 berfungsi untuk menghitung sisa hasil bagi antara angka1_1017 dan angka2_1017 menggunakan operator aritmatika modulus (%), kemudian hasilnya disimpan ke dalam variabel hasil_1017.
# 25. Baris 36 berfungsi untuk menampilkan teks "Operator Sisa Bagi" sebagai judul keluaran menggunakan fungsi print().
# 26. Baris 37 berfungsi untuk menampilkan teks "Hasil =" beserta nilai variabel hasil_1017 menggunakan fungsi print(), sehingga nilai sisa bagi dapat dilihat oleh pengguna.
# 27. Baris 38 dan baris 39 berfungsi sebagai bagian else dari percabangan kondisi, yang akan dijalankan apabila angka2_1017 bernilai 0, dengan menampilkan pesan "Angka kedua tidak boleh bernilai 0." menggunakan fungsi print().
# 28. Baris 41 berfungsi sebagai komentar yang menjelaskan bahwa bagian program selanjutnya menunjukkan penggunaan operator pangkat.
# 29. Baris 42 berfungsi untuk menghitung hasil pemangkatan angka1_1017 oleh angka2_1017 menggunakan operator aritmatika (**), kemudian hasilnya disimpan ke dalam variabel hasil_1017.
# 30. Baris 43 berfungsi untuk menampilkan teks "Operator Pangkat" sebagai judul keluaran menggunakan fungsi print().
# 31. Baris 44 berfungsi untuk menampilkan teks "Hasil =" beserta nilai variabel hasil_1017 menggunakan fungsi print(), sehingga hasil pemangkatan dapat dilihat oleh pengguna.

# %% [markdown]
# <div style="font-family:'Times New Roman', Times, serif; font-size: 18px;">
#
# ### 2.2.2 Program "Assignment_2611531017"

# %%
# Buat file dengan nama assignment_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator assignment dalam Python

angka1_1017 = int(input("Input angka-1: "))
angka2_1017 = int(input("Input angka-2: "))

print("\nNilai awal angka1_1017 =", angka1_1017)
print("Nilai angka2_1017 =", angka2_1017)

# Assignment biasa
hasil_1017 = angka1_1017
print("\nAssignment biasa (=)")
print("Hasil =", hasil_1017)

# Assignment penambahan
hasil_1017 = angka1_1017
hasil_1017 += angka2_1017
print("\nAssignment penambahan (+=)")
print("Hasil =", hasil_1017)

# Assignment pengurangan
hasil_1017 = angka1_1017
hasil_1017 -= angka2_1017
print("\nAssignment pengurangan (-=)")
print("Hasil =", hasil_1017)

# Assignment perkalian
hasil_1017 = angka1_1017
hasil_1017 *= angka2_1017
print("\nAssignment perkalian (*=)")
print("Hasil =", hasil_1017)

# Assignment pembagian, pembagian bulat, dan sisa bagi
if angka2_1017 != 0:
    hasil_1017 = angka1_1017
    hasil_1017 /= angka2_1017
    print("\nAssignment pembagian (/=)")
    print("Hasil =", hasil_1017)
    # Operator tambahan
    hasil_1017 = angka1_1017
    hasil_1017 //= angka2_1017
    print("\nAssignment pembagian bulat (//=)")
    print("Hasil =", hasil_1017)
    hasil_1017 = angka1_1017
    hasil_1017 %= angka2_1017
    print("\nAssignment sisa bagi (%=)")
    print("Hasil =", hasil_1017)
else:
    print("\nPembagian tidak dapat dilakukan.")
    print("Angka kedua tidak boleh bernilai 0.")

# Operator tambahan: assignment perpangkatan
hasil_1017 = angka1_1017
hasil_1017 **= angka2_1017
print("\nAssignment perpangkatan (**=)")
print("Hasil =", hasil_1017)
# Out:
# Nilai awal angka1_1017 = 7
# Nilai angka2_1017 = 6
#
# Assignment biasa (=)
# Hasil = 7
#
# Assignment penambahan (+=)
# Hasil = 13
#
# Assignment pengurangan (-=)
# Hasil = 1
#
# Assignment perkalian (*=)
# Hasil = 42
#
# Assignment pembagian (/=)
# Hasil = 1.1666666666666667
#
# Assignment pembagian bulat (//=)
# Hasil = 1
#
# Assignment sisa bagi (%=)
# Hasil = 1
#
# Assignment perpangkatan (**=)
# Hasil = 117649

# %% [markdown]
# <div style="font-family:'Times New Roman', Times, serif; font-size: 18px;">
#
# **Penjelasan**
#
# 1. Baris 1 sampai baris 5 berfungsi sebagai komentar yang memberikan keterangan bahwa program ini digunakan untuk membuat file bernama assignment_NIM.py, yang berisi program operator assignment dalam Python, menggunakan penamaan variabel dengan tambahan 4 digit NIM, memanfaatkan fungsi input(), serta mengonversi nilai yang dimasukkan menjadi tipe data integer. Komentar tersebut tidak dijalankan sebagai bagian dari proses program.
# 2. Baris 7 berfungsi untuk mendeklarasikan variabel angka1_1017 dan mengisinya dengan nilai yang dimasukkan pengguna melalui fungsi input(), yang kemudian dikonversi menjadi tipe data integer menggunakan fungsi int().
# 3. Baris 8 berfungsi untuk mendeklarasikan variabel angka2_1017 dengan cara yang sama seperti baris 7, yaitu menerima masukan dari pengguna dan mengonversinya menjadi tipe data integer.
# 4. Baris 10 dan baris 11 berfungsi untuk menampilkan nilai awal dari angka1_1017 dan angka2_1017 menggunakan fungsi print(), sehingga pengguna dapat melihat nilai yang telah dimasukkan sebelum diproses lebih lanjut.
# 5. Baris 13 berfungsi sebagai komentar yang menjelaskan bahwa bagian program selanjutnya menunjukkan penggunaan operator assignment biasa.
# 6. Baris 14 berfungsi untuk memberikan nilai angka1_1017 ke dalam variabel hasil_1017 menggunakan operator assignment (=).
# 7. Baris 15 dan baris 16 berfungsi untuk menampilkan judul "Assignment biasa (=)" beserta nilai variabel hasil_1017 menggunakan fungsi print().
# 8. Baris 18 berfungsi sebagai komentar yang menjelaskan bahwa bagian program selanjutnya menunjukkan penggunaan operator assignment penambahan.
# 9. Baris 19 berfungsi untuk memberikan nilai angka1_1017 ke dalam variabel hasil_1017.
# 10. Baris 20 berfungsi untuk menambahkan nilai angka2_1017 ke dalam hasil_1017 menggunakan operator assignment gabungan (+=), sehingga nilai hasil_1017 diperbarui menjadi hasil penjumlahan.
# 11. Baris 21 dan baris 22 berfungsi untuk menampilkan judul "Assignment penambahan (+=)" beserta nilai variabel hasil_1017 menggunakan fungsi print().
# 12. Baris 24 berfungsi sebagai komentar yang menjelaskan bahwa bagian program selanjutnya menunjukkan penggunaan operator assignment pengurangan.
# 13. Baris 25 berfungsi untuk memberikan nilai angka1_1017 ke dalam variabel hasil_1017.
# 14. Baris 26 berfungsi untuk mengurangkan nilai angka2_1017 dari hasil_1017 menggunakan operator assignment gabungan (-=), sehingga nilai hasil_1017 diperbarui menjadi hasil pengurangan.
# 15. Baris 27 dan baris 28 berfungsi untuk menampilkan judul "Assignment pengurangan (-=)" beserta nilai variabel hasil_1017 menggunakan fungsi print().
# 16. Baris 30 berfungsi sebagai komentar yang menjelaskan bahwa bagian program selanjutnya menunjukkan penggunaan operator assignment perkalian.
# 17. Baris 31 berfungsi untuk memberikan nilai angka1_1017 ke dalam variabel hasil_1017.
# 18. Baris 32 berfungsi untuk mengalikan hasil_1017 dengan angka2_1017 menggunakan operator assignment gabungan (*=), sehingga nilai hasil_1017 diperbarui menjadi hasil perkalian.
# 19. Baris 33 dan baris 34 berfungsi untuk menampilkan judul "Assignment perkalian (*=)" beserta nilai variabel hasil_1017 menggunakan fungsi print().
# 20. Baris 36 berfungsi sebagai komentar yang menjelaskan bahwa bagian program selanjutnya menunjukkan penggunaan operator assignment pembagian, pembagian bulat, dan sisa bagi.
# 21. Baris 37 berfungsi untuk membuat percabangan kondisi menggunakan pernyataan if, yang memeriksa apakah angka2_1017 tidak sama dengan 0 (angka2_1017 != 0), guna menghindari kesalahan pembagian dengan nol.
# 22. Baris 38 berfungsi untuk memberikan nilai angka1_1017 ke dalam variabel hasil_1017, yang hanya dijalankan apabila kondisi pada baris 37 bernilai True.
# 23. Baris 39 berfungsi untuk membagi hasil_1017 dengan angka2_1017 menggunakan operator assignment gabungan (/=), sehingga nilai hasil_1017 diperbarui menjadi hasil pembagian.
# 24. Baris 40 dan baris 41 berfungsi untuk menampilkan judul "Assignment pembagian (/=)" beserta nilai variabel hasil_1017 menggunakan fungsi print().
# 25. Baris 42 berfungsi sebagai komentar yang menjelaskan bahwa bagian program selanjutnya merupakan operator tambahan di luar materi utama, yaitu assignment pembagian bulat dan sisa bagi.
# 26. Baris 43 berfungsi untuk memberikan kembali nilai angka1_1017 ke dalam variabel hasil_1017.
# 27. Baris 44 berfungsi untuk membagi hasil_1017 dengan angka2_1017 secara bulat menggunakan operator assignment gabungan (//=), sehingga nilai hasil_1017 diperbarui menjadi hasil pembagian bulat tanpa angka desimal.
# 28. Baris 45 dan baris 46 berfungsi untuk menampilkan judul "Assignment pembagian bulat (//=)" beserta nilai variabel hasil_1017 menggunakan fungsi print().
# 29. Baris 47 berfungsi untuk memberikan kembali nilai angka1_1017 ke dalam variabel hasil_1017.
# 30. Baris 48 berfungsi untuk menghitung sisa hasil bagi antara hasil_1017 dan angka2_1017 menggunakan operator assignment gabungan (%=), sehingga nilai hasil_1017 diperbarui menjadi nilai sisa bagi.
# 31. Baris 49 dan baris 50 berfungsi untuk menampilkan judul "Assignment sisa bagi (%=)" beserta nilai variabel hasil_1017 menggunakan fungsi print().
# 32. Baris 51 sampai baris 53 berfungsi sebagai bagian else dari percabangan kondisi, yang akan dijalankan apabila angka2_1017 bernilai 0, dengan menampilkan pesan bahwa pembagian tidak dapat dilakukan karena angka kedua tidak boleh bernilai 0.
# 33. Baris 55 berfungsi sebagai komentar yang menjelaskan bahwa bagian program selanjutnya merupakan operator tambahan, yaitu assignment perpangkatan.
# 34. Baris 56 berfungsi untuk memberikan nilai angka1_1017 ke dalam variabel hasil_1017.
# 35. Baris 57 berfungsi untuk memangkatkan hasil_1017 dengan angka2_1017 menggunakan operator assignment gabungan (**=), sehingga nilai hasil_1017 diperbarui menjadi hasil pemangkatan.
# 36. Baris 58 dan baris 59 berfungsi untuk menampilkan judul "Assignment perpangkatan (**=)" beserta nilai variabel hasil_1017 menggunakan fungsi print().

# %% [markdown]
# <div style="font-family:'Times New Roman', Times, serif; font-size: 18px;">
#
# ### 2.2.3 Program "Bitwise_2611531017"

# %%
# Buat file dengan nama bitwise_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()

print("\n========================================")
print("3. OPERATOR BITWISE")
print("========================================")

angka1_1017 = int(input("Masukkan angka bitwise-1: "))
angka2_1017 = int(input("Masukkan angka bitwise-2: "))

print("\nAngka dalam bentuk desimal dan biner")
print("angka1 =", angka1_1017, "| biner =", bin(angka1_1017))
print("angka2 =", angka2_1017, "| biner =", bin(angka2_1017))

# Bitwise AND
hasil_1017 = angka1_1017 & angka2_1017
print("\nBitwise AND (&)")
print(angka1_1017, "&", angka2_1017, "=", hasil_1017)
print("Biner hasil =", bin(hasil_1017))
print("Biner hasil (8 bit) =", format(hasil_1017, "08b"))

# Bitwise OR
hasil_1017 = angka1_1017 | angka2_1017
print("\nBitwise OR (|)")
print(angka1_1017, "|", angka2_1017, "=", hasil_1017)
print("Biner hasil =", bin(hasil_1017))
print("Biner hasil (8 bit) =", format(hasil_1017, "08b"))

# Bitwise XOR
hasil_1017 = angka1_1017 ^ angka2_1017
print("\nBitwise XOR (^)")
print(angka1_1017, "^", angka2_1017, "=", hasil_1017)
print("Biner hasil =", bin(hasil_1017))
print("Biner hasil (8 bit) =", format(hasil_1017, "08b"))

# Bitwise NOT
hasil_1017 = ~angka1_1017
print("\nBitwise NOT (~)")
print("~", angka1_1017, "=", hasil_1017)
print("Biner hasil =", bin(hasil_1017))
print("Biner hasil (8 bit) =", format(hasil_1017, "08b"))

# Bitwise geser kiri
jumlah_geser_1017 = int(input("\nMasukkan jumlah pergeseran bit: "))

hasil_1017 = angka1_1017 << jumlah_geser_1017
print("\nBitwise geser kiri (<<)")
print(angka1_1017, "<<", jumlah_geser_1017, "=", hasil_1017)
print("Biner hasil =", bin(hasil_1017))
print("Biner hasil (8 bit) =", format(hasil_1017, "08b"))

# Bitwise geser kanan
hasil_1017 = angka1_1017 >> jumlah_geser_1017
print("\nBitwise geser kanan (>>)")
print(angka1_1017, ">>", jumlah_geser_1017, "=", hasil_1017)
print("Biner hasil =", bin(hasil_1017))
print("Biner hasil (8 bit) =", format(hasil_1017, "08b"))
# Out:
# ...
# 3. OPERATOR BITWISE
# ...
#
# Angka dalam bentuk desimal dan biner
# angka1 = 5 | biner = 0b101
# angka2 = 9 | biner = 0b1001
#
# Bitwise AND (&)
# 5 & 9 = 1
# Biner hasil = 0b1
# Biner hasil (8 bit) = 00000001
#
# Bitwise OR (|)
# 5 | 9 = 13
# Biner hasil = 0b1101
# Biner hasil (8 bit) = 00001101
#
# Bitwise XOR (^)
# 5 ^ 9 = 12
# Biner hasil = 0b1100
# Biner hasil (8 bit) = 00001100
#
# Bitwise NOT (~)
# ~ 5 = -6
# Biner hasil = -0b110
# Biner hasil (8 bit) = -0000110
#
# Bitwise geser kiri (<<)
# 5 << 2 = 20
# Biner hasil = 0b10100
# Biner hasil (8 bit) = 00010100
#
# Bitwise geser kanan (>>)
# 5 >> 2 = 1
# Biner hasil = 0b1
# Biner hasil (8 bit) = 00000001

# %% [markdown]
# <div style="font-family:'Times New Roman', Times, serif; font-size: 18px;">
#
# **Penjelasan**
#
# 1. Baris 1 sampai baris 3 berfungsi sebagai komentar yang memberikan keterangan bahwa program ini digunakan untuk membuat file bernama bitwise_NIM.py, menggunakan penamaan variabel dengan tambahan 4 digit NIM, serta memanfaatkan fungsi input(). Komentar tersebut tidak dijalankan sebagai bagian dari proses program.
# 2. Baris 5 sampai baris 7 berfungsi untuk menampilkan garis pembatas dan judul "3. OPERATOR BITWISE" sebagai header keluaran program menggunakan fungsi print().
# 3. Baris 9 berfungsi untuk mendeklarasikan variabel angka1_1017 dan mengisinya dengan nilai yang dimasukkan pengguna melalui fungsi input(), yang kemudian dikonversi menjadi tipe data integer menggunakan fungsi int().
# 4. Baris 10 berfungsi untuk mendeklarasikan variabel angka2_1017 dengan cara yang sama seperti baris 9, yaitu menerima masukan dari pengguna dan mengonversinya menjadi tipe data integer.
# 5. Baris 12 berfungsi untuk menampilkan teks "Angka dalam bentuk desimal dan biner" sebagai judul menggunakan fungsi print().
# 6. Baris 13 berfungsi untuk menampilkan nilai angka1_1017 beserta bentuk binernya menggunakan fungsi bin(), sehingga pengguna dapat melihat representasi biner dari angka pertama.
# 7. Baris 14 berfungsi untuk menampilkan nilai angka2_1017 beserta bentuk binernya menggunakan fungsi bin(), sehingga pengguna dapat melihat representasi biner dari angka kedua.
# 8. Baris 16 berfungsi sebagai komentar yang menjelaskan bahwa bagian program selanjutnya menunjukkan penggunaan operator bitwise AND.
# 9.  17 berfungsi untuk menghitung hasil operasi AND antara angka1_1017 dan angka2_1017 menggunakan operator bitwise (&), kemudian hasilnya disimpan dalam variabel hasil_1017.
# 10. Baris 18 dan baris 19 berfungsi untuk menampilkan judul "Bitwise AND (&)" beserta ekspresi dan hasil operasi AND menggunakan fungsi print().
# 11. Baris 20 dan baris 21 berfungsi untuk menampilkan hasil_1017 dalam bentuk biner menggunakan fungsi bin(), serta dalam format biner 8 bit menggunakan fungsi format().
# 12. Baris 23 berfungsi sebagai komentar yang menjelaskan bahwa bagian program selanjutnya menunjukkan penggunaan operator bitwise OR.
# 13. Baris 24 berfungsi untuk menghitung hasil operasi OR antara angka1_1017 dan angka2_1017 menggunakan operator bitwise (|), kemudian hasilnya disimpan dalam variabel hasil_1017.
# 14. Baris 25 dan baris 26 berfungsi untuk menampilkan judul "Bitwise OR (|)" beserta ekspresi dan hasil operasi OR menggunakan fungsi print().
# 15. Baris 27 dan baris 28 berfungsi untuk menampilkan hasil_1017 dalam bentuk biner dan format biner 8 bit menggunakan fungsi bin() dan format().
# 16. Baris 30 berfungsi sebagai komentar yang menjelaskan bahwa bagian program selanjutnya menunjukkan penggunaan operator bitwise XOR.
# 17. Baris 31 berfungsi untuk menghitung hasil operasi XOR antara angka1_1017 dan angka2_1017 menggunakan operator bitwise (^), kemudian hasilnya disimpan dalam variabel hasil_1017.
# 18. Baris 32 dan baris 33 berfungsi untuk menampilkan judul "Bitwise XOR (^)" beserta ekspresi dan hasil operasi XOR menggunakan fungsi print().
# 19. Baris 34 dan baris 35 berfungsi untuk menampilkan hasil_1017 dalam bentuk biner dan format biner 8 bit menggunakan fungsi bin() dan format().
# 20. Baris 37 berfungsi sebagai komentar yang menjelaskan bahwa bagian program selanjutnya menunjukkan penggunaan operator bitwise NOT.
# 21. Baris 38 berfungsi untuk membalik seluruh bit dari angka1_1017 menggunakan operator bitwise (~), kemudian hasilnya disimpan dalam variabel hasil_1017.
# 22. Baris 39 dan baris 40 berfungsi untuk menampilkan judul "Bitwise NOT (~)" beserta ekspresi dan hasil operasi NOT menggunakan fungsi print().
# 23. Baris 41 dan baris 42 berfungsi untuk menampilkan hasil_1017 dalam bentuk biner dan format biner 8 bit menggunakan fungsi bin() dan format().
# 24. Baris 44 berfungsi sebagai komentar yang menjelaskan bahwa bagian program selanjutnya menunjukkan penggunaan operator bitwise geser kiri.
# 25. Baris 45 berfungsi untuk mendeklarasikan variabel jumlah_geser_1017 dan mengisinya dengan nilai yang dimasukkan pengguna melalui fungsi input(), yang kemudian dikonversi menjadi tipe data integer.
# 26. Baris 47 berfungsi untuk menggeser bit dari angka1_1017 ke arah kiri sejumlah jumlah_geser_1017 menggunakan operator bitwise (<<), kemudian hasilnya disimpan dalam variabel hasil_1017.
# 27. Baris 48 dan baris 49 berfungsi untuk menampilkan judul "Bitwise geser kiri (<<)" beserta ekspresi dan hasil pergeseran bit ke kiri menggunakan fungsi print().
# 28. Baris 50 dan baris 51 berfungsi untuk menampilkan hasil_1017 dalam bentuk biner dan format biner 8 bit menggunakan fungsi bin() dan format().
# 29. Baris 53 berfungsi sebagai komentar yang menjelaskan bahwa bagian program selanjutnya menunjukkan penggunaan operator bitwise geser kanan.
# 30. Baris 54 berfungsi untuk menggeser bit dari angka1_1017 ke arah kanan sejumlah jumlah_geser_1017 menggunakan operator bitwise (>>), kemudian hasilnya disimpan dalam variabel hasil_1017.
# 31. Baris 55 dan baris 56 berfungsi untuk menampilkan judul "Bitwise geser kanan (>>)" beserta ekspresi dan hasil pergeseran bit ke kanan menggunakan fungsi print().
# 32. Baris 57 dan baris 58 berfungsi untuk menampilkan hasil_1017 dalam bentuk biner dan format biner 8 bit menggunakan fungsi bin() dan format().

# %% [markdown]
# <div style="font-family:'Times New Roman', Times, serif; font-size: 18px;">
#
# ### 2.2.4 Program "Logika_2611531017"

# %%
# Buat nama file dengan nama logika_NIM
# Nama variabel ditambah 4 digit nim terakhir contoh: a1_1234
# Program ini menggunakan fungsi input()
# Program operator logika dalam Python

# Memasukkan nilai boolean
# Input tidak peka terhadap huruf besar dan kecil
a1_1017 = input("Input nilai boolean-1 (true/false): ").strip().lower() == "true"
a2_1017 = input("Input nilai boolean-2 (true/false): ").strip().lower() == "true"

print("\nA1_1017 =", a1_1017)
print("A2_1017 =", a2_1017)

# Konjungsi: bernilai True jika keduanya True
hasil_1017 = a1_1017 and a2_1017
print("\nKonjungsi (AND)")
print("A1_1017 and A2_1017 =", hasil_1017)

# Disjungsi: bernilai True jika salah satunya True
hasil_1017 = a1_1017 or a2_1017
print("\nDisjungsi (OR)")
print("A1_1017 or A2_1017 =", hasil_1017)

# Negasi A1: membalik nilai A1
hasil_1017 = not a1_1017
print("\nNegasi A1 (NOT)")
print("not A1_1017 =", hasil_1017)

# Negasi A2: membalik nilai A2
hasil_1017 = not a2_1017
print("\nNegasi A2 (NOT)")
print("not A2_1017 =", hasil_1017)

# XOR: bernilai True jika kedua nilai berbeda
hasil_1017 = a1_1017 != a2_1017
print("\nDisjungsi Eksklusif (XOR)")
print("A1_1017 XOR A2_1017 =", hasil_1017)
# Out:
# A1_1017 = True
# A2_1017 = False
#
# Konjungsi (AND)
# A1_1017 and A2_1017 = False
#
# Disjungsi (OR)
# A1_1017 or A2_1017 = True
#
# Negasi A1 (NOT)
# not A1_1017 = False
#
# Negasi A2 (NOT)
# not A2_1017 = True
#
# Disjungsi Eksklusif (XOR)
# A1_1017 XOR A2_1017 = True

# %% [markdown]
# <div style="font-family:'Times New Roman', Times, serif; font-size: 18px;">
#
# **Penjelasan**
#
# 1. Baris 1 berfungsi sebagai komentar yang memberikan keterangan bahwa nama file dibuat dengan format logika_NIM. Komentar tersebut tidak dijalankan oleh program.
# 2. Baris 2 berfungsi sebagai komentar yang menjelaskan bahwa nama variabel ditambahkan 4 digit terakhir NIM, dengan contoh a1_1234.
# 3. Baris 3 berfungsi sebagai komentar yang menjelaskan bahwa program menggunakan fungsi input() untuk menerima masukan dari pengguna.
# 4. Baris 4 berfungsi sebagai komentar yang menjelaskan bahwa program digunakan untuk melakukan operasi logika dalam Python.
# 5. Baris 6 berfungsi sebagai komentar yang menjelaskan bahwa bagian program berikutnya digunakan untuk memasukkan nilai Boolean.
# 6. Baris 7 berfungsi sebagai komentar yang menjelaskan bahwa input yang diberikan tidak membedakan huruf besar dan huruf kecil.
# 7. Baris 8 berfungsi untuk menerima nilai Boolean pertama dari pengguna menggunakan fungsi input(). Fungsi .strip() digunakan untuk menghapus spasi di awal dan akhir input, sedangkan .lower() digunakan untuk mengubah input menjadi huruf kecil. Kemudian input dibandingkan dengan "true". Jika input sama dengan "true", hasilnya True, sedangkan jika tidak sama, hasilnya False. Hasil tersebut disimpan dalam variabel a1_1017.
# 8. Baris 9 berfungsi untuk menerima nilai Boolean kedua dari pengguna menggunakan fungsi input(). Input diproses dengan .strip() dan .lower(), kemudian dibandingkan dengan "true" sehingga menghasilkan nilai True atau False. Hasil tersebut disimpan dalam variabel a2_1017.
# 9. Baris 11 berfungsi untuk menampilkan nilai dari variabel a1_1017 menggunakan fungsi print(). \n digunakan untuk memberikan satu baris kosong sebelum hasil ditampilkan.
# 10. Baris 12 berfungsi untuk menampilkan nilai dari variabel a2_1017 menggunakan fungsi print().
# 11. Baris 14 berfungsi sebagai komentar yang menjelaskan bahwa operasi konjungsi menggunakan operator and dan bernilai True jika kedua nilai Boolean bernilai True.
# 12. Baris 15 berfungsi untuk melakukan operasi konjungsi antara a1_1017 dan a2_1017 menggunakan operator and. Hasil operasi disimpan dalam variabel hasil_1017.
# 13. Baris 16 berfungsi untuk menampilkan teks "Konjungsi (AND)" sebagai keterangan operasi yang sedang dilakukan menggunakan fungsi print(). \n digunakan untuk memberikan satu baris kosong sebelum teks ditampilkan.
# 14. Baris 17 berfungsi untuk menampilkan hasil operasi konjungsi antara a1_1017 dan a2_1017.
# 15. Baris 19 berfungsi sebagai komentar yang menjelaskan bahwa operasi disjungsi menggunakan operator or dan bernilai True jika salah satu atau kedua nilai Boolean bernilai True.
# 16. Baris 20 berfungsi untuk melakukan operasi disjungsi antara a1_1017 dan a2_1017 menggunakan operator or. Hasil operasi disimpan dalam variabel hasil_1017.
# 17. Baris 21 berfungsi untuk menampilkan teks "Disjungsi (OR)" sebagai keterangan operasi yang sedang dilakukan menggunakan fungsi print().
# 18. Baris 22 berfungsi untuk menampilkan hasil operasi disjungsi antara a1_1017 dan a2_1017.
# 19. Baris 24 berfungsi sebagai komentar yang menjelaskan bahwa operasi negasi A1 digunakan untuk membalik nilai Boolean dari a1_1017.
# 20. Baris 25 berfungsi untuk melakukan operasi negasi terhadap a1_1017 menggunakan operator not. Operator not membalik nilai Boolean, sehingga True menjadi False dan False menjadi True. Hasil operasi disimpan dalam variabel hasil_1017.
# 21. Baris 26 berfungsi untuk menampilkan teks "Negasi A1 (NOT)" sebagai keterangan operasi yang sedang dilakukan menggunakan fungsi print().
# 22. Baris 27 berfungsi untuk menampilkan hasil operasi negasi dari a1_1017.
# 23. Baris 29 berfungsi sebagai komentar yang menjelaskan bahwa operasi negasi A2 digunakan untuk membalik nilai Boolean dari a2_1017.
# 24. Baris 30 berfungsi untuk melakukan operasi negasi terhadap a2_1017 menggunakan operator not. Hasil operasi disimpan dalam variabel hasil_1017.
# 25. Baris 31 berfungsi untuk menampilkan teks "Negasi A2 (NOT)" sebagai keterangan operasi yang sedang dilakukan menggunakan fungsi print().
# 26. Baris 32 berfungsi untuk menampilkan hasil operasi negasi dari a2_1017.
# 27. Baris 34 berfungsi sebagai komentar yang menjelaskan bahwa operasi XOR atau disjungsi eksklusif bernilai True jika kedua nilai Boolean berbeda.
# 28. Baris 35 berfungsi untuk melakukan operasi XOR antara a1_1017 dan a2_1017 menggunakan operator !=. Operator != menghasilkan True jika kedua nilai berbeda dan False jika kedua nilai sama. Hasil operasi disimpan dalam variabel hasil_1017.
# 29. Baris 36 berfungsi untuk menampilkan teks "Disjungsi Eksklusif (XOR)" sebagai keterangan operasi yang sedang dilakukan menggunakan fungsi print().
# 30. Baris 37 berfungsi untuk menampilkan hasil operasi XOR antara a1_1017 dan a2_1017.

# %% [markdown]
# <div style="font-family:'Times New Roman', Times, serif; font-size: 18px;">
#
# ### 2.2.5 Program "Nama lainnya_2611531017"

# %%
# Buat file dengan nama lainnya_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()
# Program operator keanggotaan dan identitas

print("========================================")
print("1. OPERATOR KEANGGOTAAN")
print("========================================")

# Input beberapa data yang dipisahkan dengan koma
input_data_1017 = input("Masukkan beberapa angka, pisahkan dengan koma: ")

# Mengubah input menjadi list integer
data_1017 = [int(angka.strip()) for angka in input_data_1017.split(",")]

nilai_dicari_1017 = int(input("Masukkan angka yang ingin dicari: "))

# Operator in
hasil_1017 = nilai_dicari_1017 in data_1017
print("\nOperator keanggotaan IN")
print(nilai_dicari_1017, "in", data_1017, "=", hasil_1017)

# Operator not in
hasil_1017 = nilai_dicari_1017 not in data_1017
print("\nOperator keanggotaan NOT IN")
print(nilai_dicari_1017, "not in", data_1017, "=", hasil_1017)


print("\n========================================")
print("2. OPERATOR IDENTITAS")
print("========================================")

# objek1 menggunakan list dari input pengguna
objek1_1017 = data_1017

# objek2 merujuk pada objek yang sama dengan objek1
objek2_1017 = objek1_1017

# objek3 memiliki isi sama, tetapi merupakan objek baru
objek3_1017 = data_1017.copy()

print("objek1 =", objek1_1017)
print("objek2 =", objek2_1017)
print("objek3 =", objek3_1017)

# Operator is
hasil_1017 = objek1_1017 is objek2_1017
print("\nOperator identitas IS")
print("objek1 is objek2 =", hasil_1017)

# Operator is not
hasil_1017 = objek1_1017 is not objek3_1017
print("\nOperator identitas IS NOT")
print("objek1 is not objek3 =", hasil_1017)

# Membandingkan identitas dan nilai
print("\nPerbandingan identitas dan nilai")
print("objek1 is objek3 =", objek1_1017 is objek3_1017)
print("objek1 == objek3 =", objek1_1017 == objek3_1017)
# Out:
# ...
# 1. OPERATOR KEANGGOTAAN
# ...
#
# Operator keanggotaan IN
# 3 in [5, 8] = False
#
# Operator keanggotaan NOT IN
# 3 not in [5, 8] = True
#
# ...
# 2. OPERATOR IDENTITAS
# ...
# objek1 = [5, 8]
# objek2 = [5, 8]
# objek3 = [5, 8]
#
# Operator identitas IS
# objek1 is objek2 = True
#
# Operator identitas IS NOT
# objek1 is not objek3 = True
#
# Perbandingan identitas dan nilai
# objek1 is objek3 = False
# objek1 == objek3 = True

# %% [markdown]
# <div style="font-family:'Times New Roman', Times, serif; font-size: 18px;">
#
# **Penjelasan**
#
# 1. Baris 1 berfungsi sebagai komentar yang memberikan keterangan bahwa file program dibuat dengan nama "lainnya_NIM.py". Komentar ini hanya sebagai informasi dan tidak akan dijalankan oleh Python.
# 2. Baris 2 berfungsi sebagai komentar yang menjelaskan aturan penamaan variabel, yaitu setiap nama variabel ditambahkan 4 digit terakhir NIM. Contohnya, variabel "angka1" menjadi "angka1_1234".
# 3. Baris 3 berfungsi sebagai komentar yang menjelaskan bahwa program menggunakan fungsi "input()" untuk menerima data yang dimasukkan oleh pengguna.
# 4. Baris 4 berfungsi sebagai komentar yang menjelaskan bahwa program membahas operator keanggotaan dan operator identitas pada Python.
# 5. Baris 6 berfungsi untuk menampilkan garis pembatas menggunakan fungsi "print()". Garis ini digunakan agar tampilan program lebih teratur.
# 6. Baris 7 berfungsi untuk menampilkan tulisan "1. OPERATOR KEANGGOTAAN" sebagai judul bagian pertama program.
# 7. Baris 8 berfungsi untuk menampilkan kembali garis pembatas sebagai pemisah antara judul dan bagian program berikutnya.
# 8. Baris 10 berfungsi sebagai komentar yang menjelaskan bahwa pengguna akan memasukkan beberapa data yang dipisahkan menggunakan tanda koma.
# 9. Baris 11 berfungsi untuk meminta pengguna memasukkan beberapa angka menggunakan fungsi "input()". Data yang dimasukkan pengguna disimpan dalam variabel "input_data_1017" dan masih berupa string.
# 10. Baris 13 berfungsi sebagai komentar yang menjelaskan bahwa data yang telah dimasukkan akan diubah menjadi sebuah list yang berisi nilai integer.
# 11. Baris 14 berfungsi untuk mengubah data input menjadi list integer dan menyimpannya dalam "data_1017". Fungsi ".split(",")" digunakan untuk memisahkan data berdasarkan tanda koma, ".strip()" digunakan untuk menghilangkan spasi yang tidak diperlukan, dan "int()" digunakan untuk mengubah setiap data menjadi bilangan integer.
# 12. Baris 16 berfungsi untuk meminta pengguna memasukkan angka yang ingin dicari di dalam list. Fungsi "int()" digunakan agar input yang diterima berupa bilangan integer, kemudian hasilnya disimpan dalam variabel "nilai_dicari_1017".
# 13. Baris 18 berfungsi sebagai komentar yang menjelaskan bahwa bagian program berikutnya menggunakan operator keanggotaan "in".
# 14. Baris 19 berfungsi untuk memeriksa apakah nilai yang terdapat pada "nilai_dicari_1017" ada di dalam list "data_1017". Operator "in" digunakan untuk melakukan pemeriksaan tersebut. Hasilnya berupa "True" jika nilai ditemukan dan "False" jika tidak ditemukan, kemudian disimpan dalam "hasil_1017".
# 15. Baris 20 berfungsi untuk menampilkan keterangan "Operator keanggotaan IN". Tanda "\n" digunakan untuk memberikan satu baris kosong sebelum tulisan ditampilkan sehingga hasil program lebih rapi.
# 16. Baris 21 berfungsi untuk menampilkan angka yang dicari, isi dari list "data_1017", dan hasil pemeriksaan operator "in". Dengan demikian, pengguna dapat mengetahui apakah angka yang dicari terdapat dalam list atau tidak.
# 17. Baris 23 berfungsi sebagai komentar yang menjelaskan bahwa bagian program berikutnya menggunakan operator keanggotaan "not in".
# 18. Baris 24 berfungsi untuk memeriksa apakah nilai pada "nilai_dicari_1017" tidak terdapat di dalam list "data_1017". Operator "not in" akan menghasilkan "True" jika nilai tidak ditemukan dan "False" jika nilai ditemukan. Hasilnya disimpan dalam "hasil_1017".
# 19. Baris 25 berfungsi untuk menampilkan keterangan "Operator keanggotaan NOT IN". Tanda "\n" digunakan untuk memberikan jarak satu baris agar tampilan lebih rapi.
# 20. Baris 26 berfungsi untuk menampilkan angka yang dicari, isi list "data_1017", serta hasil pemeriksaan menggunakan operator "not in".
# 21. Baris 29 berfungsi untuk menampilkan garis pembatas sebagai pemisah antara bagian operator keanggotaan dan operator identitas. Tanda "\n" digunakan untuk memberikan satu baris kosong sebelum garis ditampilkan.
# 22. Baris 30 berfungsi untuk menampilkan tulisan "2. OPERATOR IDENTITAS" sebagai judul bagian kedua program.
# 23. Baris 31 berfungsi untuk menampilkan garis pembatas di bawah judul operator identitas agar tampilan program lebih terstruktur.
# 24. Baris 33 berfungsi sebagai komentar yang menjelaskan bahwa "objek1_1017" akan menggunakan list yang berasal dari input pengguna, yaitu "data_1017".
# 25. Baris 34 berfungsi untuk memberikan nilai "data_1017" kepada "objek1_1017". Dengan perintah ini, "objek1_1017" merujuk pada objek list yang sama dengan "data_1017", bukan membuat list baru.
# 26. Baris 36 berfungsi sebagai komentar yang menjelaskan bahwa "objek2_1017" akan merujuk pada objek yang sama dengan "objek1_1017".
# 27. Baris 37 berfungsi untuk membuat "objek2_1017" merujuk pada objek yang sama dengan "objek1_1017". Artinya, keduanya memiliki identitas objek yang sama.
# 28. Baris 39 berfungsi sebagai komentar yang menjelaskan bahwa "objek3_1017" akan memiliki isi yang sama dengan objek sebelumnya, tetapi dibuat sebagai objek yang berbeda.
# 29. Baris 40 berfungsi untuk membuat salinan baru dari "data_1017" menggunakan fungsi ".copy()". Hasil salinan disimpan dalam "objek3_1017". Isi list akan sama, tetapi "objek3_1017" merupakan objek yang berbeda dari "objek1_1017".
# 30. Baris 42 berfungsi untuk menampilkan nilai atau isi dari "objek1_1017" menggunakan fungsi "print()".
# 31. Baris 43 berfungsi untuk menampilkan nilai atau isi dari "objek2_1017" menggunakan fungsi "print()".
# 32. Baris 44 berfungsi untuk menampilkan nilai atau isi dari "objek3_1017" menggunakan fungsi "print()".
# 33. Baris 46 berfungsi sebagai komentar yang menjelaskan bahwa bagian program berikutnya menggunakan operator identitas "is".
# 34. Baris 47 berfungsi untuk memeriksa apakah "objek1_1017" dan "objek2_1017" merupakan objek yang sama menggunakan operator "is". Karena keduanya merujuk pada objek yang sama, hasil pemeriksaannya adalah "True", kemudian disimpan dalam "hasil_1017".
# 35. Baris 48 berfungsi untuk menampilkan keterangan "Operator identitas IS". Tanda "\n" digunakan untuk memberikan satu baris kosong sebelum tulisan ditampilkan.
# 36. Baris 49 berfungsi untuk menampilkan hasil pemeriksaan identitas antara "objek1_1017" dan "objek2_1017", yaitu apakah keduanya merupakan objek yang sama.
# 37. Baris 51 berfungsi sebagai komentar yang menjelaskan bahwa bagian program berikutnya menggunakan operator identitas "is not".
# 38. Baris 52 berfungsi untuk memeriksa apakah "objek1_1017" dan "objek3_1017" merupakan objek yang berbeda menggunakan operator "is not". Karena "objek3_1017" dibuat menggunakan ".copy()", objek tersebut berbeda dari "objek1_1017", sehingga hasilnya adalah "True".
# 39. Baris 53 berfungsi untuk menampilkan keterangan "Operator identitas IS NOT". Tanda "\n" digunakan untuk memberikan satu baris kosong sebelum tulisan ditampilkan.
# 40. Baris 54 berfungsi untuk menampilkan hasil pemeriksaan apakah "objek1_1017" dan "objek3_1017" merupakan objek yang berbeda.
# 41. Baris 56 berfungsi untuk menampilkan tulisan "Perbandingan identitas dan nilai" sebagai keterangan bahwa bagian berikutnya akan membandingkan identitas objek dan nilai yang terdapat di dalam objek.
# 42. Baris 57 berfungsi untuk membandingkan identitas "objek1_1017" dan "objek3_1017" menggunakan operator "is". Hasilnya "False" karena keduanya merupakan objek yang berbeda meskipun memiliki isi yang sama.
# 43. Baris 58 berfungsi untuk membandingkan isi atau nilai "objek1_1017" dan "objek3_1017" menggunakan operator "==". Hasilnya "True" karena isi kedua list tersebut sama.

# %% [markdown]
# <div style="font-family:'Times New Roman', Times, serif; font-size: 18px;">
#
# ### 2.2.6 Program "Perbandingan_2611531017"

# %%
# Buat file dengan nama perbandingan_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator perbandingan dalam Python

angka1_1017 = int(input("Input angka-1: "))
angka2_1017 = int(input("Input angka-2: "))

# Lebih besar dari
hasil_1017 = angka1_1017 > angka2_1017
print("\nOperator lebih besar dari")
print("angka1_1017 > angka2_1017", hasil_1017)

# Lebih kecil dari
hasil_1017 = angka1_1017 < angka2_1017
print("\nOperator lebih kecil dari")
print("angka1_1017 < angka2_1017", hasil_1017)

# Lebih besar dari atau sama dengan
hasil_1017 = angka1_1017 >= angka2_1017
print("\nOperator lebih besar dari atau sama dengan")
print("angka1_1017 >= angka2_1017", hasil_1017)

# Lebih kecil dari atau sama dengan
hasil_1017 = angka1_1017 <= angka2_1017
print("\nOperator lebih kecil dari atau sama dengan")
print("angka1_1017 <= angka2_1017 = ", hasil_1017)

# Sama dengan
hasil_1017 = angka1_1017 == angka2_1017
print("\nOperator sama dengan")
print("angka1_1017 == angka2_1017 =", hasil_1017)

# Tidak sama dengan
hasil_1017 = angka1_1017 != angka2_1017
print("\nOperator tidak sama dengan")
print("angka1_1017 != angka2_1017 =", hasil_1017)

# Tambahan: perbandingan berantai dalam Python
hasil_1017 = 0 < angka1_1017 < 100
print("\nPerbandingan berantai")
print("0 < angka1_1017 < 100 =", hasil_1017)

hasil_1017 = 0 < angka2_1017 < 100
print("0 < angka2_1017 < 100 =", hasil_1017)
# Out:
# Operator lebih besar dari
# angka1_1017 > angka2_1017 False
#
# Operator lebih kecil dari
# angka1_1017 < angka2_1017 True
#
# Operator lebih besar dari atau sama dengan
# angka1_1017 >= angka2_1017 False
#
# Operator lebih kecil dari atau sama dengan
# angka1_1017 <= angka2_1017 =  True
#
# Operator sama dengan
# angka1_1017 == angka2_1017 = False
#
# Operator tidak sama dengan
# angka1_1017 != angka2_1017 = True
#
# Perbandingan berantai
# 0 < angka1_1017 < 100 = True
# 0 < angka2_1017 < 100 = True

# %% [markdown]
# <div style="font-family:'Times New Roman', Times, serif; font-size: 18px;">
#
# **Penjelasan**
#
# 1. Baris 1 berfungsi sebagai komentar yang memberikan keterangan bahwa file program dibuat dengan nama "perbandingan_NIM.py". Komentar ini tidak dijalankan oleh Python.
# 2. Baris 2 berfungsi sebagai komentar yang menjelaskan bahwa nama variabel ditambahkan 4 digit terakhir NIM, contohnya "angka1_1234".
# 3. Baris 3 berfungsi sebagai komentar yang menjelaskan bahwa program menggunakan fungsi "input()" untuk menerima masukan dari pengguna.
# 4. Baris 4 berfungsi sebagai komentar yang menjelaskan bahwa nilai yang dimasukkan oleh pengguna akan dikonversi menjadi tipe data integer.
# 5. Baris 5 berfungsi sebagai komentar yang menjelaskan bahwa program digunakan untuk mempelajari operator perbandingan dalam Python.
# 6. Baris 7 berfungsi untuk meminta pengguna memasukkan angka pertama menggunakan fungsi "input()". Fungsi "int()" digunakan untuk mengubah input yang awalnya berupa string menjadi tipe data integer, kemudian hasilnya disimpan dalam variabel "angka1_1017".
# 7. Baris 8 berfungsi untuk meminta pengguna memasukkan angka kedua menggunakan fungsi "input()". Fungsi "int()" digunakan untuk mengubah input yang awalnya berupa string menjadi tipe data integer, kemudian hasilnya disimpan dalam variabel "angka2_1017".
# 8. Baris 10 berfungsi sebagai komentar yang menjelaskan bahwa bagian program tersebut menggunakan operator lebih besar dari (">").
# 9. Baris 11 berfungsi untuk membandingkan nilai "angka1_1017" dengan "angka2_1017" menggunakan operator ">". Hasilnya "True" jika "angka1_1017" lebih besar dari "angka2_1017", dan "False" jika tidak. Hasil perbandingan disimpan dalam variabel "hasil_1017".
# 10. Baris 12 berfungsi untuk menampilkan tulisan "Operator lebih besar dari". Tanda "\n" digunakan untuk membuat satu baris kosong sebelum tulisan ditampilkan.
# 11. Baris 13 berfungsi untuk menampilkan perbandingan "angka1_1017 > angka2_1017" beserta hasil perbandingannya, yaitu "True" atau "False".
# 12. Baris 15 berfungsi sebagai komentar yang menjelaskan bahwa bagian program tersebut menggunakan operator lebih kecil dari ("<").
# 13. Baris 16 berfungsi untuk membandingkan nilai "angka1_1017" dengan "angka2_1017" menggunakan operator "<". Hasilnya "True" jika "angka1_1017" lebih kecil dari "angka2_1017", dan "False" jika tidak. Hasil perbandingan disimpan dalam variabel "hasil_1017".
# 14. Baris 17 berfungsi untuk menampilkan tulisan "Operator lebih kecil dari". Tanda "\n" digunakan untuk membuat satu baris kosong sebelum tulisan ditampilkan.
# 15. Baris 18 berfungsi untuk menampilkan perbandingan "angka1_1017 < angka2_1017" beserta hasil perbandingannya.
# 16. Baris 20 berfungsi sebagai komentar yang menjelaskan bahwa bagian program tersebut menggunakan operator lebih besar dari atau sama dengan (">=").
# 17. Baris 21 berfungsi untuk membandingkan nilai "angka1_1017" dengan "angka2_1017" menggunakan operator ">=". Hasilnya "True" jika "angka1_1017" lebih besar atau sama dengan "angka2_1017", dan "False" jika tidak. Hasil perbandingan disimpan dalam variabel "hasil_1017".
# 18. Baris 22 berfungsi untuk menampilkan tulisan "Operator lebih besar dari atau sama dengan". Tanda "\n" digunakan untuk membuat satu baris kosong sebelum tulisan ditampilkan.
# 19. Baris 23 berfungsi untuk menampilkan perbandingan "angka1_1017 >= angka2_1017" beserta hasil perbandingannya.
# 20. Baris 25 berfungsi sebagai komentar yang menjelaskan bahwa bagian program tersebut menggunakan operator lebih kecil dari atau sama dengan ("<=").
# 21. Baris 26 berfungsi untuk membandingkan nilai "angka1_1017" dengan "angka2_1017" menggunakan operator "<=". Hasilnya "True" jika "angka1_1017" lebih kecil atau sama dengan "angka2_1017", dan "False" jika tidak. Hasil perbandingan disimpan dalam variabel "hasil_1017".
# 22. Baris 27 berfungsi untuk menampilkan tulisan "Operator lebih kecil dari atau sama dengan". Tanda "\n" digunakan untuk membuat satu baris kosong sebelum tulisan ditampilkan.
# 23. Baris 28 berfungsi untuk menampilkan perbandingan "angka1_1017 <= angka2_1017" beserta hasil perbandingannya. Tanda "= " yang terdapat di dalam tanda kutip merupakan bagian dari teks yang ditampilkan, bukan operator dalam proses perbandingan.
# 24. Baris 30 berfungsi sebagai komentar yang menjelaskan bahwa bagian program tersebut menggunakan operator sama dengan ("==").
# 25. Baris 31 berfungsi untuk membandingkan nilai "angka1_1017" dengan "angka2_1017" menggunakan operator "==". Hasilnya "True" jika kedua nilai sama dan "False" jika berbeda. Hasil perbandingan disimpan dalam variabel "hasil_1017".
# 26. Baris 32 berfungsi untuk menampilkan tulisan "Operator sama dengan". Tanda "\n" digunakan untuk membuat satu baris kosong sebelum tulisan ditampilkan.
# 27. Baris 33 berfungsi untuk menampilkan perbandingan "angka1_1017 == angka2_1017" beserta hasil perbandingannya.
# 28. Baris 35 berfungsi sebagai komentar yang menjelaskan bahwa bagian program tersebut menggunakan operator tidak sama dengan ("!=").
# 29. Baris 36 berfungsi untuk membandingkan nilai "angka1_1017" dengan "angka2_1017" menggunakan operator "!=". Hasilnya "True" jika kedua nilai berbeda dan "False" jika sama. Hasil perbandingan disimpan dalam variabel "hasil_1017".
# 30. Baris 37 berfungsi untuk menampilkan tulisan "Operator tidak sama dengan". Tanda "\n" digunakan untuk membuat satu baris kosong sebelum tulisan ditampilkan.
# 31. Baris 38 berfungsi untuk menampilkan perbandingan "angka1_1017 != angka2_1017" beserta hasil perbandingannya.
# 32. Baris 40 berfungsi sebagai komentar yang menjelaskan bahwa bagian program tersebut merupakan tambahan berupa perbandingan berantai dalam Python.
# 33. Baris 41 berfungsi untuk melakukan perbandingan berantai "0 < angka1_1017 < 100". Perintah ini memeriksa apakah "angka1_1017" lebih besar dari 0 dan lebih kecil dari 100 secara bersamaan. Hasilnya berupa "True" atau "False" dan disimpan dalam variabel "hasil_1017".
# 34. Baris 42 berfungsi untuk menampilkan tulisan "Perbandingan berantai". Tanda "\n" digunakan untuk membuat satu baris kosong sebelum tulisan ditampilkan.
# 35. Baris 43 berfungsi untuk menampilkan bentuk perbandingan "0 < angka1_1017 < 100" beserta hasil perbandingannya.
# 36. Baris 45 berfungsi untuk melakukan perbandingan berantai "0 < angka2_1017 < 100". Perintah ini memeriksa apakah "angka2_1017" lebih besar dari 0 dan lebih kecil dari 100 secara bersamaan. Hasilnya berupa "True" atau "False" dan disimpan dalam variabel "hasil_1017".
# 37. Baris 46 berfungsi untuk menampilkan bentuk perbandingan "0 < angka2_1017 < 100" beserta hasil perbandingannya.

# %% [markdown]
# <div style="font-family:'Times New Roman', Times, serif; font-size: 18px;">
#
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="images/foto soal.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>
#
# **Kode Jawaban :**
#
# a. Kode Program tugas3_2611531017

# %%
print("=== SISTEM TRANSAKSI TOKO ===")

nama_pelanggan_1017 = input("Masukkan Nama Pelanggan : ")
status_pelanggan_1017 = input("Masukkan Status Pelanggan (member/nonmember) : ")
total_belanja_1017 = int(input("Masukkan Total Belanja : "))
jumlah_barang_1017 = int(input("Masukkan Jumlah Barang : "))
promo_1017 = input("Masukkan Kode Promo : ")

print("\n=== DATA TRANSAKSI ===")
print("Nama Pelanggan                      : ", nama_pelanggan_1017)
print("Status Pelanggan (member/nonmember) : ", status_pelanggan_1017)
print("Total Belanja                       : RP ", total_belanja_1017)
print("Jumlah Barang                       : ", jumlah_barang_1017)
print("Kode Promo                          : ", promo_1017)

kode_promo_1017 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]

print("\n=== HASIL VALIDASI ===")
print(f"Belanja >= Rp200000        : {total_belanja_1017 >= 200000}")
print(f"Jumlah Barang >= 3         : {jumlah_barang_1017 >= 3}")
print(f"Status Member              : {status_pelanggan_1017 == 'member'}")
print(f"Kode Promo Tersedia        : {promo_1017 in kode_promo_1017}")
print(f"Mendapatkan Diskon         : {jumlah_barang_1017 >= 3 or total_belanja_1017 >= 200000}")
print(f"Mendapatkan Promo          : {promo_1017 in kode_promo_1017}")

print("\n=== HASIL PERHITUNGAN ===")
print(f"Diskon                     : RP{0.07 * total_belanja_1017}")
print(f"Total Pembayaran           : RP{total_belanja_1017 - 0.07 * total_belanja_1017}")
print(f"Rata-rata Harga Barang     : RP{(total_belanja_1017 - 0.07 * total_belanja_1017) / jumlah_barang_1017}")

print("\n=== HAK AKSES PELANGGAN ===")
print("Kode Hak Akses                         : ...")
print(f"Member Access                          : {status_pelanggan_1017 == 'member'}")
print(f"Promo Access                           : {promo_1017 in kode_promo_1017}")
print("Free Shipping Access                   : ...")

print("\n=== OPERASI BITWISE ===")
print("\n=== Kode Status Transaksi ===")
print(f"{format(int(status_pelanggan_1017 == 'member'), '04b')} | {format(int(total_belanja_1017 >= 200000) << 1, '04b')} | {format(int(jumlah_barang_1017 >= 3) << 2, '04b')} | {format(int(promo_1017 in kode_promo_1017) << 3, '04b')}")
print(f"Kode Biner : {format(int(status_pelanggan_1017 == 'member') << 0 | int(total_belanja_1017 >= 200000) << 1 | int(jumlah_barang_1017 >= 3) << 2 | int(promo_1017 in kode_promo_1017) << 3, '04b')}")
print(f"Kode Desimal : {int(status_pelanggan_1017 == 'member') << 0 | int(total_belanja_1017 >= 200000) << 1 | int(jumlah_barang_1017 >= 3) << 2 | int(promo_1017 in kode_promo_1017) << 3}")

print("\n=== Pemeriksaan Status ===")
print("Cek Member")
print(f"{format(int(status_pelanggan_1017 == 'member') << 0 | int(total_belanja_1017 >= 200000) << 1 | int(jumlah_barang_1017 >= 3) << 2 | int(promo_1017 in kode_promo_1017) << 3, '04b')} & {format(int(status_pelanggan_1017 == 'member') << 0, '04b')}")
print(f"Hasil Biner   : {format(int(status_pelanggan_1017 == 'member') << 0 | int(total_belanja_1017 >= 200000) << 1 | int(jumlah_barang_1017 >= 3) << 2 | int(promo_1017 in kode_promo_1017) << 3 & int(status_pelanggan_1017 == 'member') << 0, '04b')}")
print(f"Hasil Desimal : {int(status_pelanggan_1017 == 'member') << 0 | int(total_belanja_1017 >= 200000) << 1 | int(jumlah_barang_1017 >= 3) << 2 | int(promo_1017 in kode_promo_1017) << 3 & int(status_pelanggan_1017 == 'member') << 0}")

print("Cek Promo")
print(f"{format(int(status_pelanggan_1017 == 'member') << 0 | int(total_belanja_1017 >= 200000) << 1 | int(jumlah_barang_1017 >= 3) << 2 | int(promo_1017 in kode_promo_1017) << 3, '04b')} & {format(int(promo_1017 in kode_promo_1017) << 3, '04b')}")
print(f"Hasil Biner   : {format(int(status_pelanggan_1017 == 'member') << 0 | int(total_belanja_1017 >= 200000) << 1 | int(jumlah_barang_1017 >= 3) << 2 | int(promo_1017 in kode_promo_1017) << 3 & int(promo_1017 in kode_promo_1017) << 3, '04b')}")
print(f"Hasil Desimal : {int(status_pelanggan_1017 == 'member') << 0 | int(total_belanja_1017 >= 200000) << 1 | int(jumlah_barang_1017 >= 3) << 2 | int(promo_1017 in kode_promo_1017) << 3 & int(promo_1017 in kode_promo_1017) << 3}")

print("\n=== Perbandingan Status ===")
print(f"Kode transaksi : {format(int(status_pelanggan_1017 == 'member') << 0 | int(total_belanja_1017 >= 200000) << 1 | int(jumlah_barang_1017 >= 3) << 2 | int(promo_1017 in kode_promo_1017) << 3, '04b')}")
print("Kode Referensi : 1011")
print(f"{format(int(status_pelanggan_1017 == 'member') << 0 | int(total_belanja_1017 >= 200000) << 1 | int(jumlah_barang_1017 >= 3) << 2 | int(promo_1017 in kode_promo_1017) << 3, '04b')} ^ 1011 ")
print(f"Hasil Biner   : {format(int(status_pelanggan_1017 == 'member') << 0 | int(total_belanja_1017 >= 200000) << 1 | int(jumlah_barang_1017 >= 3) << 2 | int(promo_1017 in kode_promo_1017) << 3 ^ 1011, '04b')}")
print(f"Hasil Desimal : {int(status_pelanggan_1017 == 'member') << 0 | int(total_belanja_1017 >= 200000) << 1 | int(jumlah_barang_1017 >= 3) << 2 | int(promo_1017 in kode_promo_1017) << 3 ^ 1011}")

print("\n=== Shift ===")
print(f"{format(int(status_pelanggan_1017 == 'member') << 0 | int(total_belanja_1017 >= 200000) << 1 | int(jumlah_barang_1017 >= 3) << 2 | int(promo_1017 in kode_promo_1017) << 3, '04b')} << 1 ")
print(f"Hasil Biner   : {format(int(status_pelanggan_1017 == 'member') << 0 | int(total_belanja_1017 >= 200000) << 1 | int(jumlah_barang_1017 >= 3) << 2 | int(promo_1017 in kode_promo_1017) << 3 << 1, '04b')}")
print(f"Hasil Desimal : {int(status_pelanggan_1017 == 'member') << 0 | int(total_belanja_1017 >= 200000) << 1 | int(jumlah_barang_1017 >= 3) << 2 | int(promo_1017 in kode_promo_1017) << 3 << 1}")

print("\n=== SELESAI ===")
# Out:
# === SISTEM TRANSAKSI TOKO ===
#
# === DATA TRANSAKSI ===
# Nama Pelanggan                      :  rahadatul
# Status Pelanggan (member/nonmember) :  member
# Total Belanja                       : RP  3000
# Jumlah Barang                       :  8
# Kode Promo                          :  50
#
# === HASIL VALIDASI ===
# Belanja >= Rp200000        : False
# Jumlah Barang >= 3         : True
# Status Member              : True
# Kode Promo Tersedia        : False
# Mendapatkan Diskon         : True
# Mendapatkan Promo          : False
#
# === HASIL PERHITUNGAN ===
# Diskon                     : RP210.00000000000003
# Total Pembayaran           : RP2790.0
# Rata-rata Harga Barang     : RP348.75
#
# === HAK AKSES PELANGGAN ===
# Kode Hak Akses                         : ...
# Member Access                          : True
# Promo Access                           : False
# Free Shipping Access                   : ...
#
# === OPERASI BITWISE ===
#
# === Kode Status Transaksi ===
# ...

# %% [markdown]
# <div style="font-family:'Times New Roman', Times, serif; font-size: 18px;">
#
# **Penjelasan**:
# 1. Program diawali dengan "print()" untuk menampilkan tulisan “SISTEM TRANSAKSI TOKO” sebagai judul dan identitas program.
#
# 2. Program meminta pengguna memasukkan nama pelanggan melalui "input()" dan menyimpannya pada variabel "nama_pelanggan_1017".
#
# 3. Program meminta pengguna memasukkan status pelanggan, yaitu "member" atau "nonmember", kemudian menyimpannya pada variabel "status_pelanggan_1017".
#
# 4. Program meminta pengguna memasukkan total belanja. Nilai yang dimasukkan melalui "input()" diubah menjadi tipe data integer menggunakan "int()" dan disimpan pada variabel "total_belanja_1017".
#
# 5. Program meminta pengguna memasukkan jumlah barang. Data tersebut juga diubah menjadi integer menggunakan "int()" dan disimpan pada variabel "jumlah_barang_1017".
#
# 6. Program meminta pengguna memasukkan kode promo dan menyimpannya pada variabel "promo_1017".
#
# 7. Program menampilkan kembali data transaksi yang telah dimasukkan, yaitu nama pelanggan, status pelanggan, total belanja, jumlah barang, dan kode promo.
#
# 8. Program membuat list "kode_promo_1017" yang berisi tiga kode promo yang tersedia, yaitu HEMAT10, HEMAT20, dan GRATISONGKIR. List ini nantinya digunakan untuk mengecek ketersediaan kode promo.
#
# 9. Pada bagian Hasil Validasi, program mengecek apakah total belanja minimal Rp200.000 menggunakan operator perbandingan ">=". Hasilnya berupa "True" jika memenuhi syarat dan "False" jika tidak.
#
# 10. Program mengecek apakah jumlah barang minimal 3 menggunakan operator ">=", kemudian mengecek apakah status pelanggan sama dengan "member" menggunakan operator "==".
#
# 11. Program mengecek ketersediaan kode promo menggunakan operator "in", yaitu dengan melihat apakah nilai "promo_1017" terdapat di dalam list "kode_promo_1017".
#
# 12. Program menentukan apakah pelanggan mendapatkan diskon dengan operator logika "or". Kondisi bernilai "True" apabila jumlah barang minimal 3 atau total belanja minimal Rp200.000.
#
# 13. Program menentukan apakah pelanggan mendapatkan promo dengan kembali menggunakan operator "in" untuk memeriksa kode promo yang dimasukkan terhadap daftar kode promo yang tersedia.
#
# 14. Pada bagian Hasil Perhitungan, program menghitung nilai diskon sebesar 7% dari total belanja dengan mengalikan "0.07" dengan "total_belanja_1017".
#
# 15. Program menghitung total pembayaran dengan mengurangi total belanja menggunakan nilai diskon yang telah dihitung.
#
# 16. Program menghitung rata-rata harga barang dengan membagi total pembayaran setelah diskon dengan jumlah barang.
#
# 17. Pada bagian Hak Akses Pelanggan, program menampilkan beberapa informasi akses. "Member Access" ditentukan berdasarkan apakah status pelanggan sama dengan "member", sedangkan "Promo Access" ditentukan berdasarkan apakah kode promo terdapat dalam daftar promo. Sementara itu, "Kode Hak Akses" dan "Free Shipping Access" masih ditampilkan sebagai "..." karena belum memiliki proses atau nilai yang ditentukan dalam kode.
#
# 18. Pada bagian Operasi Bitwise, program mengubah hasil kondisi berupa "True" atau "False" menjadi nilai integer "1" atau "0" menggunakan "int()". Nilai tersebut kemudian digeser menggunakan operator left shift ("<<") untuk menempatkan setiap kondisi pada posisi bit yang berbeda.
#
# 19. Program membentuk kode status transaksi berdasarkan empat kondisi, yaitu status member, total belanja minimal Rp200.000, jumlah barang minimal 3, dan ketersediaan promo. Setiap kondisi ditempatkan pada posisi bit yang berbeda, yaitu posisi 0, 1, 2, dan 3.
#
# 20. Program menampilkan kode status transaksi dalam bentuk biner 4-bit menggunakan "format(..., '04b')" serta menampilkan nilai yang sama dalam bentuk desimal.
#
# 21. Pada bagian Cek Member, program menampilkan kode status transaksi dan nilai bit yang berasal dari kondisi status member menggunakan operator bitwise AND ("&"). Hasil operasi tersebut kemudian ditampilkan dalam bentuk biner dan desimal.
#
# 22. Pada bagian Cek Promo, program menampilkan kode status transaksi dan nilai bit yang berasal dari kondisi ketersediaan promo menggunakan operator bitwise AND ("&"), kemudian menampilkan hasilnya dalam bentuk biner dan desimal.
#
# 23. Pada bagian Perbandingan Status, program menampilkan kode transaksi dan kode referensi "1011". Program kemudian menggunakan operator XOR ("^") pada bagian ekspresi tersebut untuk menghasilkan nilai perbandingan dalam bentuk biner dan desimal.
#
# 24. Pada bagian Shift, program menggunakan operator left shift ("<< 1") untuk menggeser bagian nilai bit ke kiri sebanyak satu posisi, kemudian hasilnya ditampilkan dalam bentuk biner dan desimal.
#
# 25. Program diakhiri dengan "print()" yang menampilkan tulisan “SELESAI” sebagai tanda bahwa seluruh perintah dalam program telah selesai dijalankan.

# %% [markdown]
# **Pertanyaan Analisis pada Laporan**

# %% [markdown]
# <div style="font-family:'Times New Roman', Times, serif; font-size: 18px;">
# <h1 align=center> BAB III <br> KESIMPULAN </h1>
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa operator merupakan elemen dasar dalam bahasa pemrograman Python yang berfungsi untuk mengolah data dan variabel sesuai kebutuhan program, mulai dari operator aritmatika, assignment, bitwise, logika, perbandingan, keanggotaan, hingga identitas.
# Dalam konteks pemrograman Python, konsep ini memanfaatkan berbagai simbol dan kata kunci operator untuk menjalankan operasi tertentu terhadap nilai atau variabel, seperti melakukan perhitungan matematis dengan operator aritmatika, mengatur maupun memperbarui nilai variabel dengan operator assignment, memanipulasi data pada level bit dengan operator bitwise, mengevaluasi kondisi benar atau salah dengan operator logika dan perbandingan, memeriksa keberadaan suatu nilai dalam struktur data dengan operator keanggotaan, serta menguji kesamaan objek di memori dengan operator identitas, sehingga program dapat memproses data, menguji berbagai kondisi, dan mengambil keputusan secara tepat sesuai alur logika yang dirancang.

# %% [markdown]
# <h1 align=center> DAFTAR PUSTAKA </h1>
#
# [1] Python Software Foundation, "Binary Arithmetic Operations — The Python Language Reference," Python.org, 2026. [Online]. Tersedia: https://docs.python.org/3/reference/expressions.html. [Diakses 16 September 2026].
#
# [2] Python Software Foundation, "Augmented Assignment Statements — The Python Language Reference," Python.org, 2026. [Online]. Tersedia: https://docs.python.org/3/reference/simple_stmts.html. [Diakses 16 September 2026].
#
# [3] Python Software Foundation, "Bitwise Operations on Integer Types — Built-in Types," Python.org, 2026. [Online]. Tersedia: https://docs.python.org/3/library/stdtypes.html. [Diakses 16 September 2026].
#
# [4] Python Software Foundation, "Boolean Operations — The Python Language Reference," Python.org, 2026. [Online]. Tersedia: https://docs.python.org/3/reference/expressions.html. [Diakses 16 September 2026].
#
# [5] Python Software Foundation, "Membership Test Operations and Identity Comparisons — The Python Language Reference," Python.org, 2026. [Online]. Tersedia: https://docs.python.org/3/reference/expressions.html. [Diakses 16 September 2026].
#
# [6] Python Software Foundation, "Comparisons — The Python Language Reference," Python.org, 2026. [Online]. Tersedia: https://docs.python.org/3/reference/expressions.html. [Diakses 16 September 2026].
